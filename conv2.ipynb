# %%
import matplotlib.pyplot as plt
import numpy as np

# Load the image using imread()
image = plt.imread('./building.jpg')

# Display the image
plt.imshow(image, cmap='gray')


# Access the image data as a numpy array
image_array = np.array(image)

# You can now perform various operations on the image_array using numpy
# For example, you can check the shape of the array
print("Shape of the image array:", image_array.shape)
# Out:
# Shape of the image array: (400, 294)

# %%
kernel = np.array([[-1,0,-1],
                   [-2,0,-1],
                   [-1,0,-1]])

# %%
plt.imshow(image_array,cmap="gray")
